# %%
import sys, os
from pathlib import Path

cwd = Path.cwd()
repo_root = cwd
for parent in [cwd] + list(cwd.parents):
    if (parent / "src").exists():
        repo_root = parent
        break

src_path = (repo_root / "src").resolve()
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("repo_root:", repo_root)
print("src_path:", src_path)
print("src in path?", str(src_path) in sys.path)
# Out:
# repo_root: c:\Users\AIZEN\projects\auto-cleaner-pro
# src_path: C:\Users\AIZEN\projects\auto-cleaner-pro\src
# src in path? True

# %%
from auto_cleaner_pro.cleaning import load_csv_auto, clean_dataframe

# %%
example_path = repo_root / "examples" / "test_messy.csv"
df, meta = load_csv_auto(str(example_path))
cleaned, report = clean_dataframe(df)

df.head(), cleaned.head(), report
# Out:
# C:\Users\AIZEN\projects\auto-cleaner-pro\src\auto_cleaner_pro\cleaning.py:205: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(series, errors="coerce")
# (      Name AGE (Years)      joined_at Active?
#  0   Alice          30     2020-01-05      yes
#  1      Bob          25     01/06/2021      No
#  2  Charlie               March 3 2022    TRUE
#  3    Daisy          42                  false,
#        name  age_years  joined_at  active
#  0   Alice        30.0 2020-01-05    True
#  1      Bob       25.0 2021-01-06   False
#  2  Charlie        NaN 2022-03-03    True
#  3    Daisy       42.0        NaT   False,
#  {'columns_before': ['Name', 'AGE (Years)', 'joined_at', 'Active?'],
#   'columns_after': ['name', 'age_years', 'joined_at', 'active'],
#   'shape_before': (4, 4),
#   'shape_after': (4, 4),
#   'dtypes': {'name': 'object',
#    'age_years': 'float64',
#    'joined_at': 'datetime64[ns]',
#    'active': 'boolean'}})
